# %% [markdown]
# ![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)

# %% [markdown]
# # Accessing Open Data
#
# Many agencies and governments publish open data, these can be found via a web search or from Wikipedia articles such as [Open data in Canada](https://en.wikipedia.org/wiki/Open_data_in_Canada).
#
# There are different ways to access those data from a Jupyter notebook. We'll show you examples using CSV (comma separated values), XLSX (Excel), JSON (JavaScript Object Notation), and API (Application Programming Interface).

# %% [markdown]
# ## CSV Data
#
# One of the more common ways to access data is via a CSV link, as in the following example using [COVID-19 statistics from Johns Hopkins CSSE](https://github.com/CSSEGISandData/COVID-19).

# %%
# %pip install -q pyodide_http plotly
import pyodide_http
pyodide_http.patch_all()
import pandas as pd
csv_link = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/05-05-2020.csv'
df = pd.read_csv(csv_link)
df

# %% [markdown]
# ## Excel Data
#
# If you have an XLS or XLSX link, try this example from [Ontario Open Data](https://data.ontario.ca).

# %%
# %pip install -q pyodide_http plotly
import pyodide_http
pyodide_http.patch_all()
import pandas as pd
xlsx_link = 'https://data.ontario.ca/dataset/fb3a7c18-90af-453e-bc0a-a76ecc471862/resource/523b98e0-c677-4ac4-b453-08e9727cb712/download/publicly_funded_schools_xlsx_april_2020_en.xlsx'
df = pd.read_excel(xlsx_link)
df

# %% [markdown]
# ## JSON Data
#
# If the data are in JSON format, you can use this example that uses [Vancouver Open Data](opendata.vancouver.ca).

# %%
# %pip install -q pyodide_http plotly
import pyodide_http
pyodide_http.patch_all()
import requests
import pandas as pd
json_link = "https://opendata.vancouver.ca/api/records/1.0/search/?dataset=public-art&rows=500&facet=type&facet=status&facet=sitename&facet=siteaddress&facet=primarymaterial&facet=ownership&facet=neighbourhood&facet=artists&facet=photocredits"
api_response = requests.get(json_link)
data = api_response.json()['records'][0]
df = pd.DataFrame.from_dict(data)
df
# Out:
#                          datasetid                                  recordid  \
# ownership               public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# geo_point_2d            public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# artistprojectstatement  public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# registryid              public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# descriptionofwork       public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# type                    public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# status                  public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# primarymaterial         public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# geo_local_area          public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# artists                 public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# photocredits            public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# title_of_work           public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# yearofinstallation      public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# sitename                public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# siteaddress             public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# photourl                public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# locationonsite          public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# geom                    public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# neighbourhood           public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# url                     public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
# coordinates             public-art  0247724b241e2414f770a80af4fbbd4b78b5b5a4
#
#                                                                    fields  \
# ownership                                               City of Vancouver
# geo_point_2d                                     [49.261185, -123.113918]
# artistprojectstatement  A new city hall and a statue of Captain George...
# registryid                                                              1
# descriptionofwork       A full figure bronze statue of Captain George ...
# type                                                           Figurative
# status                                                           In place
# primarymaterial                                                    bronze
# geo_local_area                                             Mount Pleasant
# artists                                                                98
# photocredits                                                 Barbara Cole
# title_of_work                                    Captain George Vancouver
# yearofinstallation                                                   1936
# sitename                                              Vancouver City Hall
# siteaddress                                          453 West 12th Avenue
# photourl                {'id': '6dfd36260587f27540709ca506c4e81c', 'mi...
# locationonsite               North entrance, exterior, in front of stairs
# geom                    {'coordinates': [-123.113918, 49.261185], 'typ...
# neighbourhood                                              Mount Pleasant
# url                     https://covapp.vancouver.ca/PublicArtRegistry/...
# coordinates                                                           NaN
#
#                                         geometry          record_timestamp
# ownership                                    NaN  2024-01-15T13:22:36.239Z
# geo_point_2d                                 NaN  2024-01-15T13:22:36.239Z
# artistprojectstatement                       NaN  2024-01-15T13:22:36.239Z
# registryid                                   NaN  2024-01-15T13:22:36.239Z
# descriptionofwork                            NaN  2024-01-15T13:22:36.239Z
# type                                       Point  2024-01-15T13:22:36.239Z
# status                                       NaN  2024-01-15T13:22:36.239Z
# primarymaterial                              NaN  2024-01-15T13:22:36.239Z
# geo_local_area                               NaN  2024-01-15T13:22:36.239Z
# artists                                      NaN  2024-01-15T13:22:36.239Z
# photocredits                                 NaN  2024-01-15T13:22:36.239Z
# title_of_work                                NaN  2024-01-15T13:22:36.239Z
# yearofinstallation                           NaN  2024-01-15T13:22:36.239Z
# sitename                                     NaN  2024-01-15T13:22:36.239Z
# siteaddress                                  NaN  2024-01-15T13:22:36.239Z
# photourl                                     NaN  2024-01-15T13:22:36.239Z
# locationonsite                               NaN  2024-01-15T13:22:36.239Z
# geom                                         NaN  2024-01-15T13:22:36.239Z
# neighbourhood                                NaN  2024-01-15T13:22:36.239Z
# url                                          NaN  2024-01-15T13:22:36.239Z
# coordinates             [-123.113918, 49.261185]  2024-01-15T13:22:36.239Z

# %% [markdown]
# ## Socrata API
#
# If the data are published using Socrata, you can also use the SODA API ([Socrata Open Data Application Programming Interface](https://dev.socrata.com/)). Have a look at the [Getting Started](https://dev.socrata.com/consumers/getting-started.html) and [API Docs](https://dev.socrata.com/docs/endpoints.html) pages, as well as the following example with [Edmonton Open Data]().

# %%
# %pip install -q pyodide_http plotly
import pyodide_http
pyodide_http.patch_all()
import requests
import io
import pandas as pd

domain = 'https://data.edmonton.ca/resource/'
uuid = 'ceg3-ihxx'  # https://data.edmonton.ca/Surveys/Cat-Strategy-Edmonton-Insight-Community/ceg3-ihxx
query = 'SELECT *'

session = requests.Session()
results = session.get(domain + uuid +'.csv?$query=' + query)
df =  pd.read_csv(io.StringIO(results.content.decode('utf-8')))
df

# %% [markdown]
# # Conclusion
#
# Those are a few examples of ways to download online data into a pandas dataframe, depending on the available format.

# %% [markdown]
# [![Callysto.ca License](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-bottom.jpg?raw=true)](https://github.com/callysto/curriculum-notebooks/blob/master/LICENSE.md)
